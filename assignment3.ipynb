# %%
string="data"
string.upper()
# Out:
# 'DATA'

# %%
a="Data"
a.lower()
# Out:
# 'data'

# %%
a="Data science"
a.title()
# Out:
# 'Data Science'

# %%
a="data science"
a.capitalize()
# Out:
# 'Data science'

# %%
a="DATA"
a.isupper()
# Out:
# True

# %%
a="data6768 "
a.islower()
# Out:
# True

# %%
x="data22525"
x.isalpha()
# Out:
# False

# %%
x="1213141"
x.isalnum()
# Out:
# True

# %%
x="1213141"
x.isnumeric()
# Out:
# True

# %%
x="91-7338339898"
x.startswith("91")
# Out:
# True

# %%
x="91-73383 39898"
x.endswith("39898")
# Out:
# True

# %%
isalpha
isalnum
isnumerica
startswith
endswith

# %%
x=" science "
print(len(x))
x.strip()
print(len(x.strip()))
# Out:
# 9
# 7

# %%
x=" science "
print(len(x))
x.strip()
print(x.strip())
print(len(x.rstrip()))
# Out:
# 9
# science
# 8

# %%
x="data"
x.zfill(6)
# Out:
# '00data'

# %%
x="data"
x.ljust(10,"0")
# Out:
# 'data000000'

# %%
x="data"
x.rjust(10,"0")
# Out:
# '000000data'

# %%
x="data science data engineering"
x.split()
# Out:
# ['data', 'science', 'data', 'engineering']

# %%
x="91-73383-9898"
x.split("-")
# Out:
# ['91', '73383', '9898']

# %%
x="datat"
x.split("a")
# Out:
# ['d', 't', 't']

# %%
x="ata"
x.split("a")
# Out:
# ['', 't', '']

# %%
x="data sciencaaaae"
x.count("a")
# Out:
# 6

# %%
x="data science"
x.count("a",2,5)
# Out:
# 1

# %%
x="data scineaaaa"
x.count("a",2)
# Out:
# 5

# %%
x="da scinecex, i tata"
x.index("DA")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2760/335895744.py in <cell line: 0>()
#       1 x="da scinecex, i tata"
# ----> 2 x.index("DA")
#
# ValueError: substring not found

# %%
x="datad data"
x.replace("d","xyz")
# Out:
# 'xyzataxyz xyzata'

# %%
x="data@"
x.replace("@","")
# Out:
# 'data'

# %%
x="data SCIENCe"
x.swapcase()
# Out:
# 'DATA sciencE'

# %%
x="data"
x.center(9,"*")
# Out:
# '***data**'

# %%
x="data"
y="10"
x+"5"
# Out:
# 'data5'

# %%
x*5
# Out:
# 'datadatadatadatadata'

# %%
x="data"
#output:DAta

# %%
x.replace("da","DA")
# Out:
# 'DAta'

# %%
x[0:2].upper()+x[2:]
# Out:
# 'DAta'

# %%
x="data science"
y="machine learning"
output="****data****learning****"
