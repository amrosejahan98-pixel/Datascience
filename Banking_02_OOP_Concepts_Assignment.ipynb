# %% [markdown]
# # Banking Assignment — Object-Oriented Programming (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice classes, objects, instance/class attributes, methods, encapsulation, inheritance, polymorphism, composition, abstract classes, dataclasses, properties, protocols, and design patterns. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Create a account class for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, owner, balance=0):
        if not isinstance(account_number, str):
            raise TypeError("Account number must be a string")
        if not account_number.strip():
            raise ValueError("Account number cannot be empty")

        if not isinstance(owner, str):
            raise TypeError("Owner name must be a string")
        if not owner.strip():
            raise ValueError("Owner name cannot be empty")

        if not isinstance(balance, (int, float)):
            raise TypeError("Balance must be a number")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.account_number = account_number
        self.owner = owner
        self.__balance = float(balance)

    def deposit(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Deposit amount must be a number")
        if amount <= 0:
            raise ValueError("Deposit amount must be greater than zero")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Withdrawal amount must be a number")
        if amount <= 0:
            raise ValueError("Withdrawal amount must be greater than zero")
        if amount > self.__balance:
            raise ValueError("Insufficient balance")
        self.__balance -= amount

    def transfer(self, other_account, amount):
        if not isinstance(other_account, Account):
            raise TypeError("Target must be an Account")
        self.withdraw(amount)
        other_account.deposit(amount)

    def get_balance(self):
        return self.__balance


# Sample account
account = Account("ACC-1001", "John", 1000)

print("Account Number:", account.account_number)
print("Owner:", account.owner)
print("Initial Balance:", account.get_balance())

account.deposit(500)
print("After Deposit:", account.get_balance())

account.withdraw(200)
print("After Withdrawal:", account.get_balance())

try:
    account.withdraw(2000)
except ValueError as e:
    print("Transaction Failed:", e)
# Out:
# Account Number: ACC-1001
# Owner: John
# Initial Balance: 1000.0
# After Deposit: 1500.0
# After Withdrawal: 1300.0
# Transaction Failed: Insufficient balance

# %% [markdown]
# ### Q2. Add an initializer to accountholder for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class AccountHolder:
    def __init__(self, holder_id, name, account_number, balance=0):
        if not isinstance(holder_id, str):
            raise TypeError("Holder ID must be a string")
        if not holder_id.strip():
            raise ValueError("Holder ID cannot be empty")

        if not isinstance(name, str):
            raise TypeError("Name must be a string")
        if not name.strip():
            raise ValueError("Name cannot be empty")

        if not isinstance(account_number, str):
            raise TypeError("Account number must be a string")
        if not account_number.strip():
            raise ValueError("Account number cannot be empty")

        if not isinstance(balance, (int, float)):
            raise TypeError("Balance must be a number")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.holder_id = holder_id
        self.name = name
        self.account = Account(account_number, name, balance)


class Account:
    def __init__(self, account_number, owner, balance=0):
        self.account_number = account_number
        self.owner = owner
        self.__balance = float(balance)

    def deposit(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Deposit must be greater than zero")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Withdrawal must be greater than zero")
        if amount > self.__balance:
            raise ValueError("Insufficient balance")
        self.__balance -= amount

    def get_balance(self):
        return self.__balance


# Sample AccountHolder with account ACC-1002
holder = AccountHolder("H001", "John", "ACC-1002", 2000)

print("Holder ID:", holder.holder_id)
print("Name:", holder.name)
print("Account Number:", holder.account.account_number)
print("Initial Balance:", holder.account.get_balance())

holder.account.deposit(500)
print("After Deposit:", holder.account.get_balance())

holder.account.withdraw(300)
print("After Withdrawal:", holder.account.get_balance())

try:
    holder.account.withdraw(3000)
except ValueError as e:
    print("Transaction Failed:", e)
# Out:
# Holder ID: H001
# Name: John
# Account Number: ACC-1002
# Initial Balance: 2000.0
# After Deposit: 2500.0
# After Withdrawal: 2200.0
# Transaction Failed: Insufficient balance

# %% [markdown]
# ### Q3. Represent an transfer object for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, owner, balance=0):
        if not isinstance(account_number, str):
            raise TypeError("Account number must be a string")
        if not account_number.strip():
            raise ValueError("Account number cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.account_number = account_number
        self.owner = owner
        self.__balance = float(balance)

    def deposit(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Deposit amount must be greater than zero")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Withdrawal amount must be greater than zero")
        if amount > self.__balance:
            raise ValueError("Insufficient balance")
        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class Transfer:
    def __init__(self, transfer_id, from_account, to_account, amount):
        if not isinstance(transfer_id, str):
            raise TypeError("Transfer ID must be a string")
        if not transfer_id.strip():
            raise ValueError("Transfer ID cannot be empty")
        if not isinstance(from_account, Account):
            raise TypeError("Source must be an Account")
        if not isinstance(to_account, Account):
            raise TypeError("Destination must be an Account")
        if amount <= 0:
            raise ValueError("Transfer amount must be greater than zero")

        self.transfer_id = transfer_id
        self.from_account = from_account
        self.to_account = to_account
        self.amount = amount

    def execute(self):
        self.from_account.withdraw(self.amount)
        self.to_account.deposit(self.amount)


# ACC-1003
account1 = Account("ACC-1003", "John", 5000)
account2 = Account("ACC-1004", "David", 1000)

transfer = Transfer("TR001", account1, account2, 1500)
transfer.execute()

print("Transfer ID:", transfer.transfer_id)
print("From Account:", account1.account_number)
print("To Account:", account2.account_number)
print("Transfer Amount:", transfer.amount)
print("ACC-1003 Balance:", account1.get_balance())
print("ACC-1004 Balance:", account2.get_balance())

# Failure case
try:
    failed_transfer = Transfer("TR002", account1, account2, 10000)
    failed_transfer.execute()
except ValueError as e:
    print("Transfer Failed:", e)
# Out:
# Transfer ID: TR001
# From Account: ACC-1003
# To Account: ACC-1004
# Transfer Amount: 1500
# ACC-1003 Balance: 3500.0
# ACC-1004 Balance: 2500.0
# Transfer Failed: Insufficient balance

# %% [markdown]
# ### Q4. Add a method that calculates line total for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass
from decimal import Decimal
from typing import List


@dataclass(frozen=True)
class Transaction:
    kind: str
    amount: Decimal

    def __post_init__(self):
        if self.kind not in {"deposit", "withdrawal"}:
            raise ValueError("Transaction type must be deposit or withdrawal")

        if self.amount <= 0:
            raise ValueError("Transaction amount must be positive")


class BankAccount:
    def __init__(self, account_id: str, balance: Decimal = Decimal("0")):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    @property
    def account_id(self):
        return self.__account_id

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount: Decimal):
        if amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount: Decimal):
        if amount <= 0:
            raise ValueError("Withdrawal must be positive")
        if amount > self.__balance:
            raise ValueError("Insufficient funds")
        self.__balance -= amount


class BankingCase:
    def __init__(self, account: BankAccount, transactions: List[Transaction]):
        self.account = account
        self.transactions = transactions

    def line_total(self) -> Decimal:
        """Calculate the net total of all banking transactions."""
        total = Decimal("0")

        for transaction in self.transactions:
            if transaction.kind == "deposit":
                total += transaction.amount
            else:
                total -= transaction.amount

        return total

# %% [markdown]
# ### Q5. Use a class attribute for branch name for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    branch_name = "Nellore Main Branch"   # class attribute

    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    @property
    def account_id(self):
        return self.__account_id

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Deposit must be positive")

        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Withdrawal must be positive")
        if amount > self.__balance:
            raise ValueError("Insufficient funds")

        self.__balance -= amount

# %% [markdown]
# ### Q6. Write a readable __str__ method for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_id, balance):
        self.__account_id = account_id
        self.__balance = balance

    def __str__(self):
        return f"Account ID: {self.__account_id}, Balance: ₹{self.__balance:.2f}"


# Sample reference
account = BankAccount("ACC-1006", 7500)

print(account)
# Out:
# Account ID: ACC-1006, Balance: ₹7500.00

# %% [markdown]
# ### Q7. Compare two account references with __eq__ for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_id, balance):
        self.__account_id = account_id
        self.__balance = balance

    def __eq__(self, other):
        if not isinstance(other, BankAccount):
            return False
        return self.__account_id == other.__account_id


# Sample reference
account1 = BankAccount("ACC-1007", 5000)
account2 = BankAccount("ACC-1007", 7000)

print(account1 == account2)
# Out:
# True

# %% [markdown]
# ### Q8. Protect a amount with a property for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_id, amount):
        self.__account_id = account_id
        self.__amount = amount

    @property
    def amount(self):
        return self.__amount

    @amount.setter
    def amount(self, value):
        if not isinstance(value, (int, float)):
            raise TypeError("Amount must be a number")
        if value < 0:
            raise ValueError("Amount cannot be negative")
        self.__amount = value


# Sample reference
account = BankAccount("ACC-1008", 5000)

print(account.amount)

account.amount = 7500
print(account.amount)
# Out:
# 5000
# 7500

# %% [markdown]
# ### Q9. Create portfolio and add_item for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_id, balance):
        self.__account_id = account_id
        self.__balance = balance

    def __str__(self):
        return f"{self.__account_id}: ₹{self.__balance:.2f}"


class Portfolio:
    def __init__(self):
        self.__items = []

    def add_item(self, account):
        if not isinstance(account, BankAccount):
            raise TypeError("Only BankAccount objects can be added")
        self.__items.append(account)

    def __str__(self):
        return "\n".join(str(account) for account in self.__items)


# Sample reference
account = BankAccount("ACC-1009", 10000)

portfolio = Portfolio()
portfolio.add_item(account)

print(portfolio)
# Out:
# ACC-1009: ₹10000.00

# %% [markdown]
# ### Q10. Model a branchaddress for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BranchAddress:
    def __init__(self, city, state, pincode):
        if not city or not state:
            raise ValueError("City and state cannot be empty")
        if not isinstance(pincode, int):
            raise TypeError("Pincode must be an integer")

        self.city = city
        self.state = state
        self.pincode = pincode

    def __str__(self):
        return f"{self.city}, {self.state} - {self.pincode}"


class BankAccount:
    def __init__(self, account_id, balance, branch_address):
        self.__account_id = account_id
        self.__balance = balance
        self.branch_address = branch_address

    def __str__(self):
        return (
            f"Account ID: {self.__account_id}, "
            f"Balance: ₹{self.__balance:.2f}, "
            f"Branch Address: {self.branch_address}"
        )


# Sample reference
address = BranchAddress("Nellore", "Andhra Pradesh", 524001)
account = BankAccount("ACC-1010", 8000, address)

print(account)
# Out:
# Account ID: ACC-1010, Balance: ₹8000.00, Branch Address: Nellore, Andhra Pradesh - 524001

# %% [markdown]
# ### Q11. Use a static method to validate account reference for banking case 1; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:

    @staticmethod
    def validate_account_reference(account_reference):
        if not isinstance(account_reference, str):
            return False

        if not account_reference.startswith("ACC-"):
            return False

        number = account_reference[4:]

        return number.isdigit() and len(number) == 4


# Sample reference
reference = "ACC-1011"

print(BankAccount.validate_account_reference(reference))
# Out:
# True

# %% [markdown]
# ### Q12. Use a class method as an alternate constructor for banking case 1; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_id, balance):
        self.__account_id = account_id
        self.__balance = balance

    @classmethod
    def from_reference(cls, account_reference):
        if not isinstance(account_reference, str):
            raise TypeError("Account reference must be a string")

        if not account_reference.startswith("ACC-"):
            raise ValueError("Invalid account reference")

        return cls(account_reference, 0)

    def __str__(self):
        return f"Account ID: {self.__account_id}, Balance: ₹{self.__balance:.2f}"


# Sample reference
account = BankAccount.from_reference("ACC-1012")

print(account)
# Out:
# Account ID: ACC-1012, Balance: ₹0.00

# %% [markdown]
# ### Q13. Track object count for banking case 1; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    object_count = 0

    def __init__(self, account_id, balance):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

        BankAccount.object_count += 1

    @classmethod
    def get_object_count(cls):
        return cls.object_count


# Sample reference
account1 = BankAccount("ACC-1013", 5000)
account2 = BankAccount("ACC-1014", 3000)

print(account1)
print("Total accounts created:", BankAccount.get_object_count())
# Out:
# <__main__.BankAccount object at 0x78b106757380>
# Total accounts created: 2

# %% [markdown]
# ### Q14. Model a loyaltyaccount for banking case 1; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_id, balance):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def __str__(self):
        return f"Account ID: {self.__account_id}, Balance: ₹{self.__balance:.2f}"


class LoyaltyAccount(BankAccount):
    def __init__(self, account_id, balance, loyalty_points=0):
        super().__init__(account_id, balance)

        if loyalty_points < 0:
            raise ValueError("Loyalty points cannot be negative")

        self.loyalty_points = loyalty_points

    def add_points(self, points):
        if points <= 0:
            raise ValueError("Points must be positive")
        self.loyalty_points += points


# Sample reference
account = LoyaltyAccount("ACC-1014", 10000, 100)

account.add_points(50)

print(account)
print("Loyalty points:", account.loyalty_points)
# Out:
# Account ID: ACC-1014, Balance: ₹10000.00
# Loyalty points: 150

# %% [markdown]
# ### Q15. Create a supplier class for banking case 1; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Supplier:
    def __init__(self, name, supplier_id):
        if not name:
            raise ValueError("Supplier name cannot be empty")
        if not supplier_id:
            raise ValueError("Supplier ID cannot be empty")

        self.name = name
        self.supplier_id = supplier_id

    def __str__(self):
        return f"{self.name} ({self.supplier_id})"


class BankAccount:
    def __init__(self, account_id, balance, supplier):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")
        if not isinstance(supplier, Supplier):
            raise TypeError("supplier must be a Supplier object")

        self.__account_id = account_id
        self.__balance = balance
        self.supplier = supplier

    def __str__(self):
        return (
            f"Account: {self.__account_id}, "
            f"Balance: ₹{self.__balance:.2f}, "
            f"Supplier: {self.supplier}"
        )


# Sample reference
supplier = Supplier("ABC Finance Services", "SUP-101")
account = BankAccount("ACC-1015", 12000, supplier)

print(account)
# Out:
# Account: ACC-1015, Balance: ₹12000.00, Supplier: ABC Finance Services (SUP-101)

# %% [markdown]
# ### Q16. Create a account class for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    @property
    def account_id(self):
        return self.__account_id

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Deposit must be positive")

        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Withdrawal must be positive")
        if amount > self.__balance:
            raise ValueError("Insufficient funds")

        self.__balance -= amount

    def __str__(self):
        return f"Account ID: {self.__account_id}, Balance: ₹{self.__balance:.2f}"


# Sample reference
account = Account("ACC-1016", 5000)

print(account)
account.deposit(1000)
account.withdraw(500)

print(account)
# Out:
# Account ID: ACC-1016, Balance: ₹5000.00
# Account ID: ACC-1016, Balance: ₹5500.00

# %% [markdown]
# ### Q17. Add an initializer to accountholder for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class AccountHolder:
    def __init__(self, holder_id, name, account_reference):
        if not holder_id:
            raise ValueError("Holder ID cannot be empty")
        if not name:
            raise ValueError("Name cannot be empty")
        if not account_reference:
            raise ValueError("Account reference cannot be empty")

        self.holder_id = holder_id
        self.name = name
        self.account_reference = account_reference

    def __str__(self):
        return (
            f"Holder ID: {self.holder_id}, "
            f"Name: {self.name}, "
            f"Account: {self.account_reference}"
        )


# Sample reference
holder = AccountHolder(
    "H-1017",
    "Rahul",
    "ACC-1017"
)

print(holder)
# Out:
# Holder ID: H-1017, Name: Rahul, Account: ACC-1017

# %% [markdown]
# ### Q18. Represent an transfer object for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, from_account, to_account, amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Transfer amount must be positive")

        self.from_account = from_account
        self.to_account = to_account
        self.amount = amount

    def __str__(self):
        return (
            f"Transfer: ₹{self.amount:.2f} "
            f"from {self.from_account} to {self.to_account}"
        )


# Sample reference
transfer = Transfer("ACC-1018", "ACC-2001", 2000)

print(transfer)
# Out:
# Transfer: ₹2000.00 from ACC-1018 to ACC-2001

# %% [markdown]
# ### Q19. Add a method that calculates line total for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        self.__account_id = account_id
        self.__balance = balance
        self.transactions = []

    def add_transaction(self, transaction_type, amount):
        if transaction_type not in ("deposit", "withdrawal"):
            raise ValueError("Invalid transaction type")
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")
        if amount <= 0:
            raise ValueError("Amount must be positive")

        self.transactions.append((transaction_type, amount))

    def line_total(self):
        total = 0

        for transaction_type, amount in self.transactions:
            if transaction_type == "deposit":
                total += amount
            else:
                total -= amount

        return total


# Sample reference
account = Account("ACC-1019")

account.add_transaction("deposit", 5000)
account.add_transaction("withdrawal", 1000)
account.add_transaction("deposit", 2000)

print("Line Total:", account.line_total())
# Out:
# Line Total: 6000

# %% [markdown]
# ### Q20. Use a class attribute for branch name for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    branch_name = "Nellore Main Branch"   # Class attribute

    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Withdrawal must be positive")
        if amount > self.__balance:
            raise ValueError("Insufficient funds")
        self.__balance -= amount

    def __str__(self):
        return (
            f"Account: {self.__account_id}, "
            f"Balance: ₹{self.__balance:.2f}, "
            f"Branch: {Account.branch_name}"
        )


# Sample reference
account = Account("ACC-1020", 8000)

print(account)
# Out:
# Account: ACC-1020, Balance: ₹8000.00, Branch: Nellore Main Branch

# %% [markdown]
# ### Q21. Write a readable __str__ method for banking case 2; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    def __str__(self):
        return f"Account ID: {self.__account_id}, Balance: ₹{self.__balance:.2f}"


# Sample reference
account = Account("ACC-1021", 7500)

print(account)
# Out:
# Account ID: ACC-1021, Balance: ₹7500.00

# %% [markdown]
# ### Q22. Compare two account references with __eq__ for banking case 2; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    def __eq__(self, other):
        if not isinstance(other, Account):
            return False
        return self.__account_id == other.__account_id


# Sample reference
account1 = Account("ACC-1022", 5000)
account2 = Account("ACC-1022", 8000)
account3 = Account("ACC-1023", 5000)

print(account1 == account2)
print(account1 == account3)
# Out:
# True
# False

# %% [markdown]
# ### Q23. Protect a amount with a property for banking case 2; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, amount=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if amount < 0:
            raise ValueError("Amount cannot be negative")

        self.__account_id = account_id
        self.__amount = amount

    @property
    def amount(self):
        return self.__amount

    @amount.setter
    def amount(self, value):
        if not isinstance(value, (int, float)):
            raise TypeError("Amount must be a number")
        if value < 0:
            raise ValueError("Amount cannot be negative")

        self.__amount = value


# Sample reference
account = Account("ACC-1023", 5000)

print("Initial amount:", account.amount)

account.amount = 7500

print("Updated amount:", account.amount)
# Out:
# Initial amount: 5000
# Updated amount: 7500

# %% [markdown]
# ### Q24. Create portfolio and add_item for banking case 2; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    def __str__(self):
        return f"{self.__account_id}: ₹{self.__balance:.2f}"


class Portfolio:
    def __init__(self):
        self.__items = []

    def add_item(self, account):
        if not isinstance(account, Account):
            raise TypeError("Only Account objects can be added")
        self.__items.append(account)

    def __str__(self):
        return "\n".join(str(account) for account in self.__items)


# Sample reference
account = Account("ACC-1024", 10000)

portfolio = Portfolio()
portfolio.add_item(account)

print(portfolio)
# Out:
# ACC-1024: ₹10000.00

# %% [markdown]
# ### Q25. Model a branchaddress for banking case 2; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BranchAddress:
    def __init__(self, city, state, pincode):
        if not city or not state:
            raise ValueError("City and state cannot be empty")
        if not isinstance(pincode, int):
            raise TypeError("Pincode must be an integer")

        self.city = city
        self.state = state
        self.pincode = pincode

    def __str__(self):
        return f"{self.city}, {self.state} - {self.pincode}"


class Account:
    def __init__(self, account_id, balance, branch_address):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")
        if not isinstance(branch_address, BranchAddress):
            raise TypeError("branch_address must be a BranchAddress")

        self.__account_id = account_id
        self.__balance = balance
        self.branch_address = branch_address

    def __str__(self):
        return (
            f"Account: {self.__account_id}, "
            f"Balance: ₹{self.__balance:.2f}, "
            f"Branch Address: {self.branch_address}"
        )


# Sample reference
address = BranchAddress("Nellore", "Andhra Pradesh", 524001)
account = Account("ACC-1025", 9000, address)

print(account)
# Out:
# Account: ACC-1025, Balance: ₹9000.00, Branch Address: Nellore, Andhra Pradesh - 524001

# %% [markdown]
# ### Q26. Use a static method to validate account reference for banking case 2; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:

    @staticmethod
    def validate_account_reference(reference):
        if not isinstance(reference, str):
            return False

        if not reference.startswith("ACC-"):
            return False

        number = reference[4:]

        return number.isdigit() and len(number) == 4


# Sample reference
reference = "ACC-1026"

print(Account.validate_account_reference(reference))
# Out:
# True

# %% [markdown]
# ### Q27. Use a class method as an alternate constructor for banking case 2; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    @classmethod
    def from_reference(cls, reference):
        if not isinstance(reference, str):
            raise TypeError("Reference must be a string")

        if not reference.startswith("ACC-"):
            raise ValueError("Invalid account reference")

        return cls(reference, 0)

    def __str__(self):
        return f"Account ID: {self.__account_id}, Balance: ₹{self.__balance:.2f}"


# Sample reference
account = Account.from_reference("ACC-1027")

# %% [markdown]
# ### Q28. Track object count for banking case 2; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    object_count = 0

    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

        Account.object_count += 1

    @classmethod
    def get_object_count(cls):
        return cls.object_count


# Sample reference
account1 = Account("ACC-1028", 5000)
account2 = Account("ACC-1029", 3000)

print("Accounts created:", Account.get_object_count())
# Out:
# Accounts created: 2

# %% [markdown]
# ### Q29. Model a loyaltyaccount for banking case 2; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.__account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def __str__(self):
        return f"Account ID: {self.__account_id}, Balance: ₹{self.__balance:.2f}"


class LoyaltyAccount(Account):
    def __init__(self, account_id, balance=0, loyalty_points=0):
        super().__init__(account_id, balance)

        if loyalty_points < 0:
            raise ValueError("Loyalty points cannot be negative")

        self.loyalty_points = loyalty_points

    def add_points(self, points):
        if points <= 0:
            raise ValueError("Points must be positive")
        self.loyalty_points += points


# Sample reference
account = LoyaltyAccount("ACC-1029", 10000, 100)

account.add_points(50)print(account)
print("Loyalty Points:", account.loyalty_points)
# Out:
# Account ID: ACC-1029, Balance: ₹10000.00
# Loyalty Points: 150

# %% [markdown]
# ### Q30. Create a supplier class for banking case 2; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Supplier:
    def __init__(self, supplier_id, name):
        if not supplier_id:
            raise ValueError("Supplier ID cannot be empty")
        if not name:
            raise ValueError("Supplier name cannot be empty")

        self.supplier_id = supplier_id
        self.name = name

    def __str__(self):
        return f"{self.name} ({self.supplier_id})"


class Account:
    def __init__(self, account_id, balance, supplier):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")
        if not isinstance(supplier, Supplier):
            raise TypeError("supplier must be a Supplier object")

        self.__account_id = account_id
        self.__balance = balance
        self.supplier = supplier

    def __str__(self):
        return (
            f"Account: {self.__account_id}, "
            f"Balance: ₹{self.__balance:.2f}, "
            f"Supplier: {self.supplier}"
        )


# Sample reference
supplier = Supplier("SUP-1030", "ABC Banking Services")
account = Account("ACC-1030", 15000, supplier)

print(account)
# Out:
# Account: ACC-1030, Balance: ₹15000.00, Supplier: ABC Banking Services (SUP-1030)

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Inherit perishableaccount from account for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import date


class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Invalid account ID")
        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid initial balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")
        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def transfer(self, target, amount):
        if not isinstance(target, Account):
            raise TypeError("Target must be an Account")

        self.withdraw(amount)
        target.deposit(amount)


class PerishableAccount(Account):
    def __init__(self, account_id, balance, expiry_date):
        super().__init__(account_id, balance)

        if not isinstance(expiry_date, date):
            raise TypeError("expiry_date must be a date")

        self.expiry_date = expiry_date

    def _check_active(self):
        if date.today() > self.expiry_date:
            raise ValueError("Account has expired")

    def deposit(self, amount):
        self._check_active()
        super().deposit(amount)

    def withdraw(self, amount):
        self._check_active()
        super().withdraw(amount)

    def transfer(self, target, amount):
        self._check_active()
        super().transfer(target, amount)

# %% [markdown]
# ### Q32. Override a discount method for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")
        if amount > self.__balance:
            raise ValueError("Insufficient balance")
        self.__balance -= amount

    def discount(self, amount):
        if not isinstance(amount, (int, float)) or amount < 0:
            raise ValueError("Invalid amount")

        # Normal account: 5% discount
        return amount * 0.05


class DiscountAccount(Account):
    def discount(self, amount):
        if not isinstance(amount, (int, float)) or amount < 0:
            raise ValueError("Invalid amount")

        # Special account: 10% discount
        return amount * 0.10

# %% [markdown]
# ### Q33. Use polymorphic payment processors for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod


class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount


class PaymentProcessor(ABC):

    @abstractmethod
    def process_payment(self, account, amount):
        pass


class CardProcessor(PaymentProcessor):

    def process_payment(self, account, amount):
        account.withdraw(amount)
        return f"Card payment of {amount} processed"


class UPIProcessor(PaymentProcessor):

    def process_payment(self, account, amount):
        account.withdraw(amount)
        return f"UPI payment of {amount} processed"


def make_payment(processor, account, amount):
    return processor.process_payment(account, amount)

# %% [markdown]
# ### Q34. Compose transfer from transferline objects for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")
        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")
        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount


class TransferLine:
    def __init__(self, source, destination, amount):
        if not isinstance(source, Account):
            raise TypeError("Source must be an Account")
        if not isinstance(destination, Account):
            raise TypeError("Destination must be an Account")
        if source is destination:
            raise ValueError("Source and destination cannot be the same")
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Transfer amount must be positive")

        self.source = source
        self.destination = destination
        self.amount = amount

    def execute(self):
        self.source.withdraw(self.amount)
        self.destination.deposit(self.amount)


class Transfer:
    def __init__(self, lines):
        if not isinstance(lines, list) or not lines:
            raise ValueError("Transfer must contain at least one line")
        if not all(isinstance(line, TransferLine) for line in lines):
            raise TypeError("All items must be TransferLine objects")

        self.lines = lines

    def execute(self):
        for line in self.lines:
            line.execute()

# %% [markdown]
# ### Q35. Define an abstract paymentmethod for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod


class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount


class PaymentMethod(ABC):

    @abstractmethod
    def pay(self, account, amount):
        """Process a payment using the account."""
        pass


class CardPayment(PaymentMethod):

    def pay(self, account, amount):
        account.withdraw(amount)
        return f"Card payment of ₹{amount} completed"


class UPIPayment(PaymentMethod):

    def pay(self, account, amount):
        account.withdraw(amount)
        return f"UPI payment of ₹{amount} completed"

# %% [markdown]
# ### Q36. Use a dataclass for inventoryrecord for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass


@dataclass
class InventoryRecord:
    item_id: str
    item_name: str
    quantity: int
    unit_price: float

    def __post_init__(self):
        if not isinstance(self.item_id, str) or not self.item_id:
            raise ValueError("Item ID cannot be empty")

        if not isinstance(self.item_name, str) or not self.item_name:
            raise ValueError("Item name cannot be empty")

        if not isinstance(self.quantity, int) or self.quantity < 0:
            raise ValueError("Quantity cannot be negative")

        if not isinstance(self.unit_price, (int, float)) or self.unit_price < 0:
            raise ValueError("Unit price cannot be negative")

    @property
    def total_value(self):
        return self.quantity * self.unit_price


class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

# %% [markdown]
# ### Q37. Implement a custom iterator for portfolio for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount


class PortfolioIterator:
    def __init__(self, accounts):
        self.accounts = accounts
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index >= len(self.accounts):
            raise StopIteration

        account = self.accounts[self.index]
        self.index += 1
        return account


class Portfolio:
    def __init__(self):
        self.__accounts = []

    def add_account(self, account):
        if not isinstance(account, Account):
            raise TypeError("Only Account objects can be added")

        self.__accounts.append(account)

    def __iter__(self):
        return PortfolioIterator(self.__accounts)

# %% [markdown]
# ### Q38. Use multiple inheritance carefully for timestampeditem for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime


class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")

        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount


class TimestampedItem:
    def __init__(self):
        self.created_at = datetime.now()

        if not isinstance(self.created_at, datetime):
            raise TypeError("Invalid timestamp")


class TimestampedAccount(Account, TimestampedItem):
    def __init__(self, account_id, balance=0):
        Account.__init__(self, account_id, balance)

# %% [markdown]
# ### Q39. Create a account factory for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance=0):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def transfer(self, target, amount):
        if not isinstance(target, Account):
            raise TypeError("Target must be an Account")

        self.withdraw(amount)
        target.deposit(amount)


class SavingsAccount(Account):
    pass


class CurrentAccount(Account):
    pass


class AccountFactory:

    @staticmethod
    def create_account(account_type, account_id, balance=0):
        if not isinstance(account_type, str):
            raise TypeError("Account type must be a string")

        account_type = account_type.lower()

        if account_type == "savings":
            return SavingsAccount(account_id, balance)

        if account_type == "current":
            return CurrentAccount(account_id, balance)

        raise ValueError("Unsupported account type")

# %% [markdown]
# ### Q40. Apply a strategy for interest offers for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod


class Account:
    def __init__(self, account_id, balance=0, interest_strategy=None):
        if not isinstance(account_id, str) or not account_id:
            raise ValueError("Account ID cannot be empty")

        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        self.account_id = account_id
        self.__balance = balance
        self.interest_strategy = interest_strategy

    @property
    def balance(self):
        return self.__balance

    def deposit(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if not isinstance(amount, (int, float)) or amount <= 0:
            raise ValueError("Withdrawal must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def calculate_interest(self):
        if self.interest_strategy is None:
            raise ValueError("No interest strategy configured")

        return self.interest_strategy.calculate(self.__balance)


class InterestStrategy(ABC):

    @abstractmethod
    def calculate(self, balance):
        pass


class StandardInterest(InterestStrategy):

    def calculate(self, balance):
        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        return balance * 0.04


class PremiumInterest(InterestStrategy):

    def calculate(self, balance):
        if not isinstance(balance, (int, float)) or balance < 0:
            raise ValueError("Invalid balance")

        return balance * 0.07

# %% [markdown]
# ### Q41. Encapsulate balance reservation for banking case 1; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.__balance = balance
        self.__reserved = 0

    def reserve(self, amount):
        if amount <= 0 or amount > self.__balance - self.__reserved:
            raise ValueError("Invalid reservation")
        self.__reserved += amount

    def available_balance(self):
        return self.__balance - self.__reserved


acc = Account(1000)
acc.reserve(250)

print(acc.available_balance())  # 750
# Out:
# 750

# %% [markdown]
# ### Q42. Model aggregation between branch and employees for banking case 1; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Employee:
    def __init__(self, name):
        self.name = name


class Branch:
    def __init__(self, name):
        self.name = name
        self.employees = []

    def add_employee(self, employee):
        if not isinstance(employee, Employee):
            raise TypeError("Invalid employee")
        self.employees.append(employee)


branch = Branch("Main Branch")
emp = Employee("Rahul")

branch.add_employee(emp)

print(branch.name)
print(emp.name)
# Out:
# Main Branch
# Rahul

# %% [markdown]
# ### Q43. Serialize an transfer to a dictionary for banking case 1; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, reference, sender, receiver, amount):
        self.reference = reference
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def to_dict(self):
        return {
            "reference": self.reference,
            "sender": self.sender,
            "receiver": self.receiver,
            "amount": self.amount
        }


transfer = Transfer("ACC-1043", "A101", "A102", 500)
print(transfer.to_dict())
# Out:
# {'reference': 'ACC-1043', 'sender': 'A101', 'receiver': 'A102', 'amount': 500}

# %% [markdown]
# ### Q44. Implement a repository abstraction for banking case 1; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, reference, balance):
        self.reference = reference
        self.__balance = balance


class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.reference] = account

    def find(self, reference):
        return self.accounts.get(reference)


repo = AccountRepository()
account = Account("ACC-1044", 1000)

repo.save(account)

print(repo.find("ACC-1044").reference)
# Out:
# ACC-1044

# %% [markdown]
# ### Q45. Apply dependency injection to checkout for banking case 1; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentService:
    def pay(self, account, amount):
        account.withdraw(amount)
        return True


class Checkout:
    def __init__(self, payment_service):
        self.payment_service = payment_service

    def checkout(self, account, amount):
        return self.payment_service.pay(account, amount)


account = Account("ACC-1045", 1000)
service = PaymentService()
checkout = Checkout(service)

checkout.checkout(account, 200)

# %% [markdown]
# ### Q46. Inherit perishableaccount from account for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, reference, balance):
        self.reference = reference
        self.__balance = balance

    def withdraw(self, amount):
        if amount <= 0 or amount > self.__balance:
            raise ValueError("Invalid withdrawal")
        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class PerishableAccount(Account):
    def __init__(self, reference, balance, expired=False):
        super().__init__(reference, balance)
        self.expired = expired

    def withdraw(self, amount):
        if self.expired:
            raise ValueError("Account expired")
        super().withdraw(amount)


account = PerishableAccount("ACC-1046", 1000)
account.withdraw(200)

print(account.get_balance())
# Out:
# 800

# %% [markdown]
# ### Q47. Override a discount method for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def discount(self, amount):
        return amount * 0.05


class PremiumAccount(Account):
    def discount(self, amount):
        return amount * 0.10


account = PremiumAccount()
print(account.discount(1000))
# Out:
# 100.0

# %% [markdown]
# ### Q48. Use polymorphic payment processors for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentProcessor:
    def pay(self, amount):
        raise NotImplementedError


class CardPayment(PaymentProcessor):
    def pay(self, amount):
        return f"Card payment: ₹{amount}"


class UPIPayment(PaymentProcessor):
    def pay(self, amount):
        return f"UPI payment: ₹{amount}"


processor = UPIPayment()
print(processor.pay(500))
# Out:
# UPI payment: ₹500

# %% [markdown]
# ### Q49. Compose transfer from transferline objects for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, account, amount):
        self.account = account
        self.amount = amount


class Transfer:
    def __init__(self, reference):
        self.reference = reference
        self.lines = []

    def add_line(self, line):
        if not isinstance(line, TransferLine):
            raise TypeError("Invalid transfer line")
        self.lines.append(line)

    def total(self):
        return sum(line.amount for line in self.lines)


transfer = Transfer("ACC-1049")
transfer.add_line(TransferLine("A101", 500))
transfer.add_line(TransferLine("A102", 300))

print(transfer.total())  # 800
# Out:
# 800

# %% [markdown]
# ### Q50. Define an abstract paymentmethod for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class CardPayment(PaymentMethod):
    def pay(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        return f"Paid ₹{amount} by card"


payment = CardPayment()
print(payment.pay(500))
# Out:
# Paid ₹500 by card

# %% [markdown]
# ### Q51. Use a dataclass for inventoryrecord for banking case 2; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    reference: str
    item: str
    quantity: int


record = InventoryRecord("ACC-1051", "Laptop", 10)

print(record)
# Out:
# InventoryRecord(reference='ACC-1051', item='Laptop', quantity=10)

# %% [markdown]
# ### Q52. Implement a custom iterator for portfolio for banking case 2; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, records):
        self.records = records

    def __iter__(self):
        return iter(self.records)


portfolio = Portfolio(["ACC-1052", "ACC-1053", "ACC-1054"])

for record in portfolio:
    print(record)
# Out:
# ACC-1052
# ACC-1053
# ACC-1054

# %% [markdown]
# ### Q53. Use multiple inheritance carefully for timestampeditem for banking case 2; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class Item:
    def __init__(self, reference):
        self.reference = reference


class Timestamped:
    def __init__(self):
        self.timestamp = datetime.now()


class TimestampedItem(Item, Timestamped):
    def __init__(self, reference):
        Item.__init__(self, reference)
        Timestamped.__init__(self)


item = TimestampedItem("ACC-1053")

print(item.reference)
print(item.timestamp)
# Out:
# ACC-1053
# 2026-09-06 17:42:59.846885

# %% [markdown]
# ### Q54. Create a account factory for banking case 2; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, reference, balance):
        self.reference = reference
        self.balance = balance


class SavingsAccount(Account):
    pass


class CurrentAccount(Account):
    pass


class AccountFactory:
    @staticmethod
    def create(account_type, reference, balance):
        if account_type == "savings":
            return SavingsAccount(reference, balance)
        elif account_type == "current":
            return CurrentAccount(reference, balance)
        else:
            raise ValueError("Invalid account type")


account = AccountFactory.create("savings", "ACC-1054", 1000)

print(account.reference)
print(type(account).__name__)
# Out:
# ACC-1054
# SavingsAccount

# %% [markdown]
# ### Q55. Apply a strategy for interest offers for banking case 2; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class RegularInterest:
    def calculate(self, balance):
        return balance * 0.05


class PremiumInterest:
    def calculate(self, balance):
        return balance * 0.08


class Account:
    def __init__(self, reference, balance, strategy):
        self.reference = reference
        self.balance = balance
        self.strategy = strategy

    def interest(self):
        return self.strategy.calculate(self.balance)


account = Account("ACC-1055", 1000, PremiumInterest())

print(account.interest())
# Out:
# 80.0

# %% [markdown]
# ### Q56. Encapsulate balance reservation for banking case 2; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, reference, balance):
        self.reference = reference
        self.__balance = balance
        self.__reserved = 0

    def reserve(self, amount):
        if amount <= 0 or amount > self.__balance - self.__reserved:
            raise ValueError("Invalid reservation")
        self.__reserved += amount

    def available_balance(self):
        return self.__balance - self.__reserved


account = Account("ACC-1056", 1000)
account.reserve(300)

print(account.available_balance())  # 700
# Out:
# 700

# %% [markdown]
# ### Q57. Model aggregation between branch and employees for banking case 2; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Employee:
    def __init__(self, name):
        self.name = name


class Branch:
    def __init__(self, reference):
        self.reference = reference
        self.employees = []

    def add_employee(self, employee):
        if not isinstance(employee, Employee):
            raise TypeError("Invalid employee")
        self.employees.append(employee)


branch = Branch("ACC-1057")
employee = Employee("Ali")

branch.add_employee(employee)

print(branch.reference)
print(employee.name)
# Out:
# ACC-1057
# Ali

# %% [markdown]
# ### Q58. Serialize an transfer to a dictionary for banking case 2; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, reference, sender, receiver, amount):
        self.reference = reference
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def to_dict(self):
        return {
            "reference": self.reference,
            "sender": self.sender,
            "receiver": self.receiver,
            "amount": self.amount
        }


transfer = Transfer("ACC-1058", "A101", "A102", 500)

print(transfer.to_dict())
# Out:
# {'reference': 'ACC-1058', 'sender': 'A101', 'receiver': 'A102', 'amount': 500}

# %% [markdown]
# ### Q59. Implement a repository abstraction for banking case 2; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, reference, balance):
        self.reference = reference
        self.__balance = balance


class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.reference] = account

    def find(self, reference):
        return self.accounts.get(reference)


repo = AccountRepository()
account = Account("ACC-1059", 1000)

repo.save(account)

print(repo.find("ACC-1059").reference)
# Out:
# ACC-1059

# %% [markdown]
# ### Q60. Apply dependency injection to checkout for banking case 2; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Checkout:
    def __init__(self, payment_service):
        self.payment_service = payment_service

    def checkout(self, account_id, amount):
        return self.payment_service.pay(account_id, amount)


class BankPaymentService:
    def __init__(self, bank):
        self.bank = bank

    def pay(self, account_id, amount):
        account = self.bank.get_account(account_id)

        if amount <= 0:
            return False

        if account.balance < amount:
            return False

        account.withdraw(amount)
        return True

# %% [markdown]
# ### Q61. Inherit perishableaccount from account for banking case 3; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import date

class Account:
    def __init__(self, account_id, balance):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if not isinstance(balance, (int, float)):
            raise TypeError("Balance must be a number")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.account_id = account_id
        self._balance = balance

    @property
    def balance(self):
        return self._balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount


class PerishableAccount(Account):
    def __init__(self, account_id, balance, expiry_date):
        super().__init__(account_id, balance)
        self.expiry_date = expiry_date

    def withdraw(self, amount):
        if date.today() > self.expiry_date:
            raise ValueError("Account has expired")
        super().withdraw(amount)

# %% [markdown]
# ### Q62. Override a discount method for banking case 3; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance):
        self.account_id = account_id
        self._balance = balance

    def discount(self, amount):
        return amount * 0.05


class PremiumAccount(Account):
    def discount(self, amount):
        return amount * 0.10

# %% [markdown]
# ### Q63. Use polymorphic payment processors for banking case 3; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankPayment:
    def pay(self, account, amount):
        account.withdraw(amount)
        return "Bank payment successful"


class CardPayment:
    def pay(self, account, amount):
        account.withdraw(amount)
        return "Card payment successful"


class Checkout:
    def __init__(self, processor):
        self.processor = processor

    def checkout(self, account, amount):
        return self.processor.pay(account, amount)


class Account:
    def __init__(self, account_id, balance):
        self.account_id = account_id
        self._balance = balance

    @property
    def balance(self):
        return self._balance

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount

# %% [markdown]
# ### Q64. Compose transfer from transferline objects for banking case 3; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, sender, receiver, amount):
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def execute(self):
        self.sender.withdraw(self.amount)
        self.receiver.deposit(self.amount)


class Transfer:
    def __init__(self, lines):
        self.lines = lines

    def execute(self):
        for line in self.lines:
            line.execute()

# %% [markdown]
# ### Q65. Define an abstract paymentmethod for banking case 3; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, account, amount):
        pass


class BankPayment(PaymentMethod):
    def pay(self, account, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        account.withdraw(amount)
        return "Payment successful"


class Account:
    def __init__(self, account_id, balance):
        self.account_id = account_id
        self._balance = balance

    @property
    def balance(self):
        return self._balance

    def withdraw(self, amount):
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount


# Sample reference: ACC-1065
account = Account("ACC-1065", 5000)

payment = BankPayment()
print(payment.pay(account, 1000))
print("Final balance:", account.balance)
# Out:
# Payment successful
# Final balance: 4000

# %% [markdown]
# ### Q66. Use a dataclass for inventoryrecord for banking case 3; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    account_id: str
    item: str
    quantity: int

    def __post_init__(self):
        if not self.account_id:
            raise ValueError("Account ID cannot be empty")
        if not isinstance(self.quantity, int):
            raise TypeError("Quantity must be an integer")
        if self.quantity < 0:
            raise ValueError("Quantity cannot be negative")


# Sample reference: ACC-1066
record = InventoryRecord("ACC-1066", "Bank Cheque", 10)

print(record)
# Out:
# InventoryRecord(account_id='ACC-1066', item='Bank Cheque', quantity=10)

# %% [markdown]
# ### Q67. Implement a custom iterator for portfolio for banking case 3; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance):
        self.account_id = account_id
        self._balance = balance

    @property
    def balance(self):
        return self._balance


class Portfolio:
    def __init__(self):
        self.accounts = []

    def add_account(self, account):
        self.accounts.append(account)

    def __iter__(self):
        return PortfolioIterator(self.accounts)


class PortfolioIterator:
    def __init__(self, accounts):
        self.accounts = accounts
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index >= len(self.accounts):
            raise StopIteration

        account = self.accounts[self.index]
        self.index += 1
        return account


# Sample reference: ACC-1067
portfolio = Portfolio()
portfolio.add_account(Account("ACC-1067", 5000))
portfolio.add_account(Account("ACC-1068", 3000))

for account in portfolio:
    print(account.account_id, account.balance)
# Out:
# ACC-1067 5000
# ACC-1068 3000

# %% [markdown]
# ### Q68. Use multiple inheritance carefully for timestampeditem for banking case 3; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class Account:
    def __init__(self, account_id, balance):
        self.account_id = account_id
        self._balance = balance

    @property
    def balance(self):
        return self._balance


class Timestamped:
    def __init__(self):
        self.timestamp = datetime.now()


class TimestampedItem(Account, Timestamped):
    def __init__(self, account_id, balance):
        Account.__init__(self, account_id, balance)
        Timestamped.__init__(self)


# Sample reference
item = TimestampedItem("ACC-1068", 5000)

print(item.account_id)
print(item.balance)
print(item.timestamp)
# Out:
# ACC-1068
# 5000
# 2026-09-07 11:31:10.895129

# %% [markdown]
# ### Q69. Create a account factory for banking case 3; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_id, balance):
        if not account_id:
            raise ValueError("Account ID cannot be empty")
        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.account_id = account_id
        self._balance = balance

    @property
    def balance(self):
        return self._balance


class SavingsAccount(Account):
    pass


class CurrentAccount(Account):
    pass


class AccountFactory:
    @staticmethod
    def create(account_type, account_id, balance):
        if account_type == "savings":
            return SavingsAccount(account_id, balance)
        elif account_type == "current":
            return CurrentAccount(account_id, balance)
        else:
            raise ValueError("Invalid account type")


# Sample reference: ACC-1069
account = AccountFactory.create("savings", "ACC-1069", 5000)

print(type(account).__name__)
print(account.account_id)
print(account.balance)
# Out:
# SavingsAccount
# ACC-1069
# 5000

# %% [markdown]
# ### Q70. Apply a strategy for interest offers for banking case 3; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InterestStrategy:
    def calculate(self, balance):
        raise NotImplementedError


class RegularInterest(InterestStrategy):
    def calculate(self, balance):
        return balance * 0.04


class PremiumInterest(InterestStrategy):
    def calculate(self, balance):
        return balance * 0.06


class Account:
    def __init__(self, account_id, balance, strategy):
        self.account_id = account_id
        self._balance = balance
        self.strategy = strategy

    def interest(self):
        return self.strategy.calculate(self._balance)


# Sample reference: ACC-1070
account = Account(
    "ACC-1070",
    5000,
    PremiumInterest()
)

print("Interest:", account.interest())
# Out:
# Interest: 300.0

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design an extensible pricing engine for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PricingRule:
    def apply(self, amount):
        raise NotImplementedError


class RegularPricing(PricingRule):
    def apply(self, amount):
        return amount


class PremiumPricing(PricingRule):
    def apply(self, amount):
        return amount * 0.90   # 10% discount


class PricingEngine:
    def __init__(self, rule):
        self.rule = rule

    def calculate(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        return self.rule.apply(amount)


# Sample reference: ACC-1071
engine = PricingEngine(PremiumPricing())

print("Account: ACC-1071")
print("Final price:", engine.calculate(1000))
# Out:
# Account: ACC-1071
# Final price: 900.0

# %% [markdown]
# ### Q72. Implement an observer for low balance for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LowBalanceObserver:
    def update(self, account):
        print(f"Low balance alert: {account.account_id}")


class Account:
    def __init__(self, account_id, balance, limit=1000):
        self.account_id = account_id
        self._balance = balance
        self.limit = limit
        self.observers = []

    @property
    def balance(self):
        return self._balance

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        if amount <= 0 or amount > self._balance:
            raise ValueError("Invalid withdrawal")

        self._balance -= amount

        if self._balance < self.limit:
            for observer in self.observers:
                observer.update(self)


# Sample reference
account = Account("ACC-1072", 2000)

observer = LowBalanceObserver()
account.add_observer(observer)

account.withdraw(1200)

print("Final balance:", account.balance)
# Out:
# Low balance alert: ACC-1072
# Final balance: 800

# %% [markdown]
# ### Q73. Build a state machine for transfer status for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from enum import Enum

class Status(Enum):
    PENDING = 1
    PROCESSING = 2
    COMPLETED = 3
    FAILED = 4
    CANCELLED = 5

class Transfer:
    def __init__(self, ref, source, dest, amount):
        self.ref = ref
        self.source = source
        self.dest = dest
        self.amount = amount
        self.status = Status.PENDING

    def process(self):
        self.status = Status.PROCESSING
        try:
            self.source.withdraw(self.amount)
            self.dest.deposit(self.amount)
            self.status = Status.COMPLETED
        except Exception:
            self.status = Status.FAILED

# %% [markdown]
# ### Q74. Create an immutable money value object for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from decimal import Decimal


class Money:
    def __init__(self, amount, currency):
        if amount is None or Decimal(str(amount)) < 0:
            raise ValueError("Invalid amount")

        if not currency:
            raise ValueError("Invalid currency")

        self._amount = Decimal(str(amount))
        self._currency = currency

    @property
    def amount(self):
        return self._amount

    @property
    def currency(self):
        return self._currency


class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        self.account_no = account_no
        self._balance = balance

    def deposit(self, money):
        if money.currency != self._balance.currency:
            raise ValueError("Currency mismatch")

        self._balance = Money(
            self._balance.amount + money.amount,
            self._balance.currency
        )

    def withdraw(self, money):
        if money.currency != self._balance.currency:
            raise ValueError("Currency mismatch")

        if money.amount > self._balance.amount:
            raise ValueError("Insufficient balance")

        self._balance = Money(
            self._balance.amount - money.amount,
            self._balance.currency
        )

    @property
    def balance(self):
        return self._balance


# Example: ACC-1074
account = BankAccount(
    "ACC-1074",
    Money(1000, "INR")
)

account.deposit(Money(500, "INR"))

print("Account: ACC-1074")
print("Initial Balance: ₹1000")
print("Deposit: ₹500")
print("Final Balance: ₹", account.balance.amount)

try:
    account.withdraw(Money(2000, "INR"))
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Account: ACC-1074
# Initial Balance: ₹1000
# Deposit: ₹500
# Final Balance: ₹ 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q75. Implement a unit-of-work transaction for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount

    def get_balance(self):
        return self._balance


class UnitOfWork:
    def transfer(self, sender, receiver, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        # Check first, so failed transaction changes nothing
        if amount > sender.get_balance():
            raise ValueError("Transaction failed: Insufficient balance")

        sender.withdraw(amount)
        receiver.deposit(amount)

        print("Transaction committed successfully")


# Example: ACC-1075
acc1075 = BankAccount("ACC-1075", 1000)
acc1076 = BankAccount("ACC-1076", 500)

uow = UnitOfWork()

print("Before Transfer:")
print("ACC-1075:", acc1075.get_balance())
print("ACC-1076:", acc1076.get_balance())

uow.transfer(acc1075, acc1076, 300)

print("After Transfer:")
print("ACC-1075:", acc1075.get_balance())
print("ACC-1076:", acc1076.get_balance())
# Out:
# Before Transfer:
# ACC-1075: 1000
# ACC-1076: 500
# Transaction committed successfully
# After Transfer:
# ACC-1075: 700
# ACC-1076: 800

# %% [markdown]
# ### Q76. Separate domain and infrastructure layers for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount

    def get_balance(self):
        return self._balance


# INFRASTRUCTURE LAYER
class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_no] = account

    def find(self, account_no):
        return self.accounts.get(account_no)


# APPLICATION/SERVICE LAYER
class BankService:
    def __init__(self, repository):
        self.repository = repository

    def deposit(self, account_no, amount):
        account = self.repository.find(account_no)

        if account is None:
            raise ValueError("Account not found")

        account.deposit(amount)
        self.repository.save(account)


# Example: ACC-1076
repository = AccountRepository()

account = BankAccount("ACC-1076", 1000)
repository.save(account)

service = BankService(repository)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

service.deposit("ACC-1076", 500)

print("After Deposit:", account.get_balance())

try:
    service.deposit("ACC-1076", -100)
except ValueError as e:
    print("Failed:", e)
# Out:
# Account: ACC-1076
# Initial Balance: 1000
# After Deposit: 1500
# Failed: Invalid amount

# %% [markdown]
# ### Q77. Design a plugin-ready payment architecture for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid payment amount")

        if amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= amount

    def get_balance(self):
        return self._balance


# PAYMENT PLUGIN
class PaymentPlugin:
    def pay(self, amount):
        raise NotImplementedError


class CardPayment(PaymentPlugin):
    def pay(self, amount):
        print("Payment processed using Card")


class UPIPayment(PaymentPlugin):
    def pay(self, amount):
        print("Payment processed using UPI")


# PAYMENT SERVICE
class PaymentService:
    def __init__(self, plugin):
        self.plugin = plugin

    def make_payment(self, account, amount):
        if self.plugin is None:
            raise ValueError("Payment plugin not available")

        account.withdraw(amount)
        self.plugin.pay(amount)


# Example: ACC-1077
account = BankAccount("ACC-1077", 1000)

payment = PaymentService(UPIPayment())

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

payment.make_payment(account, 300)

print("Final Balance:", account.get_balance())

try:
    payment.make_payment(account, 1000)
except ValueError as e:
    print("Payment failed:", e)
# Out:
# Account: ACC-1077
# Initial Balance: 1000
# Payment processed using UPI
# Final Balance: 700
# Payment failed: Insufficient balance

# %% [markdown]
# ### Q78. Implement a descriptor for positive amounts for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = "_" + name

    def __set__(self, instance, value):
        if not isinstance(value, (int, float)):
            raise TypeError("Amount must be a number")

        if value <= 0:
            raise ValueError("Amount must be positive")

        setattr(instance, self.name, value)

    def __get__(self, instance, owner):
        return getattr(instance, self.name, 0)


class BankAccount:
    amount = PositiveAmount()

    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        self.account_no = account_no
        self._balance = balance

    def deposit(self, amount):
        self.amount = amount
        self._balance += self.amount

    def withdraw(self, amount):
        self.amount = amount

        if self.amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= self.amount

    def get_balance(self):
        return self._balance


# Example: ACC-1078
account = BankAccount("ACC-1078", 1000)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.deposit(500)

print("After Deposit:", account.get_balance())

try:
    account.deposit(-100)
except ValueError as e:
    print("Failed:", e)
# Out:
# Account: ACC-1078
# Initial Balance: 1000
# After Deposit: 1500
# Failed: Amount must be positive

# %% [markdown]
# ### Q79. Use cooperative inheritance with super for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_no, **kwargs):
        super().__init__(**kwargs)
        if not account_no:
            raise ValueError("Invalid account number")
        self.account_no = account_no


class BalanceMixin:
    def __init__(self, balance=0, **kwargs):
        super().__init__(**kwargs)
        if balance < 0:
            raise ValueError("Invalid balance")
        self._balance = balance


class BankAccount(BalanceMixin, Account):
    def __init__(self, account_no, balance):
        super().__init__(
            account_no=account_no,
            balance=balance
        )

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount

    def get_balance(self):
        return self._balance


# Example: ACC-1079
account = BankAccount("ACC-1079", 1000)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.deposit(500)

print("After Deposit:", account.get_balance())

try:
    account.withdraw(2000)
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Account: ACC-1079
# Initial Balance: 1000
# After Deposit: 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q80. Refactor a god object using solid for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount

    def get_balance(self):
        return self._balance


class AccountRepository:
    def save(self, account):
        print("Account saved:", account.account_no)


class NotificationService:
    def notify(self, message):
        print("Notification:", message)


class BankingService:
    def __init__(self, repository, notification):
        self.repository = repository
        self.notification = notification

    def deposit(self, account, amount):
        account.deposit(amount)
        self.repository.save(account)
        self.notification.notify("Deposit successful")


# Example: ACC-1080
account = BankAccount("ACC-1080", 1000)

service = BankingService(
    AccountRepository(),
    NotificationService()
)

print("Initial Balance:", account.get_balance())

service.deposit(account, 500)

print("Final Balance:", account.get_balance())

try:
    account.withdraw(2000)
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Initial Balance: 1000
# Account saved: ACC-1080
# Notification: Deposit successful
# Final Balance: 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q81. Design an extensible pricing engine for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def get_balance(self):
        return self._balance


class PricingRule:
    def calculate(self, amount):
        raise NotImplementedError


class FixedFeeRule(PricingRule):
    def __init__(self, fee):
        if fee < 0:
            raise ValueError("Invalid fee")
        self.fee = fee

    def calculate(self, amount):
        return amount + self.fee


class PercentageFeeRule(PricingRule):
    def __init__(self, percentage):
        if percentage < 0:
            raise ValueError("Invalid percentage")
        self.percentage = percentage

    def calculate(self, amount):
        return amount + (amount * self.percentage / 100)


class PricingEngine:
    def __init__(self, rule):
        self.rule = rule

    def final_amount(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        return self.rule.calculate(amount)


# Example: ACC-1081
account = BankAccount("ACC-1081", 1000)

engine = PricingEngine(FixedFeeRule(50))

amount = 500
final_amount = engine.final_amount(amount)

print("Account:", account.account_no)
print("Transaction Amount:", amount)
print("Fee:", 50)
print("Final Amount:", final_amount)
# Out:
# Account: ACC-1081
# Transaction Amount: 500
# Fee: 50
# Final Amount: 550

# %% [markdown]
# ### Q82. Implement an observer for low balance for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LowBalanceObserver:
    def __init__(self, limit):
        self.limit = limit

    def update(self, account):
        if account.get_balance() < self.limit:
            print("Alert: Low balance!")


class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance
        self.observers = []

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= amount
        self.notify()

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        self._balance += amount
        self.notify()

    def notify(self):
        for observer in self.observers:
            observer.update(self)

    def get_balance(self):
        return self._balance


# Example: ACC-1082
account = BankAccount("ACC-1082", 1000)

observer = LowBalanceObserver(500)
account.add_observer(observer)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.withdraw(600)

print("Final Balance:", account.get_balance())
# Out:
# Account: ACC-1082
# Initial Balance: 1000
# Alert: Low balance!
# Final Balance: 400

# %% [markdown]
# ### Q83. Build a state machine for transfer status for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= amount

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        self._balance += amount

    def get_balance(self):
        return self._balance


class Transfer:
    def __init__(self, sender, receiver, amount):
        if amount <= 0:
            raise ValueError("Invalid transfer amount")

        self.sender = sender
        self.receiver = receiver
        self.amount = amount
        self.status = "PENDING"

    def process(self):
        try:
            self.status = "PROCESSING"

            self.sender.withdraw(self.amount)
            self.receiver.deposit(self.amount)

            self.status = "COMPLETED"

        except ValueError:
            self.status = "FAILED"


# Example: ACC-1083
sender = BankAccount("ACC-1083", 1000)
receiver = BankAccount("ACC-1084", 500)

transfer = Transfer(sender, receiver, 300)

print("Initial Status:", transfer.status)

transfer.process()

print("Final Status:", transfer.status)
print("ACC-1083 Balance:", sender.get_balance())
print("ACC-1084 Balance:", receiver.get_balance())
# Out:
# Initial Status: PENDING
# Final Status: COMPLETED
# ACC-1083 Balance: 700
# ACC-1084 Balance: 800

# %% [markdown]
# ### Q84. Create an immutable money value object for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Money:
    def __init__(self, amount, currency):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")

        if amount < 0:
            raise ValueError("Amount cannot be negative")

        if not currency:
            raise ValueError("Currency cannot be empty")

        self.__amount = amount
        self.__currency = currency

    @property
    def amount(self):
        return self.__amount

    @property
    def currency(self):
        return self.__currency


class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, money):
        self.__balance += money.amount

    def withdraw(self, money):
        if money.amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= money.amount

    def get_balance(self):
        return self.__balance


# Example: ACC-1084
account = BankAccount("ACC-1084", 1000)

print("Account:", account.account_no)
print("Initial Balance: ₹1000")

account.deposit(Money(500, "INR"))

print("After Deposit: ₹", account.get_balance())

try:
    account.withdraw(Money(2000, "INR"))
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Account: ACC-1084
# Initial Balance: ₹1000
# After Deposit: ₹ 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q85. Implement a unit-of-work transaction for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class UnitOfWork:
    def transfer(self, sender, receiver, amount):
        if amount <= 0:
            raise ValueError("Invalid transfer amount")

        if amount > sender.get_balance():
            raise ValueError("Transaction failed: Insufficient balance")

        sender.withdraw(amount)
        receiver.deposit(amount)

        print("Transaction committed successfully")


# Example: ACC-1085
sender = BankAccount("ACC-1085", 1000)
receiver = BankAccount("ACC-1086", 500)

uow = UnitOfWork()

print("Before Transfer:")
print("ACC-1085:", sender.get_balance())
print("ACC-1086:", receiver.get_balance())

uow.transfer(sender, receiver, 300)

print("After Transfer:")
print("ACC-1085:", sender.get_balance())
print("ACC-1086:", receiver.get_balance())
# Out:
# Before Transfer:
# ACC-1085: 1000
# ACC-1086: 500
# Transaction committed successfully
# After Transfer:
# ACC-1085: 700
# ACC-1086: 800

# %% [markdown]
# ### Q86. Separate domain and infrastructure layers for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


# INFRASTRUCTURE LAYER
class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_no] = account

    def find(self, account_no):
        return self.accounts.get(account_no)


# APPLICATION LAYER
class BankService:
    def __init__(self, repository):
        self.repository = repository

    def deposit(self, account_no, amount):
        account = self.repository.find(account_no)

        if account is None:
            raise ValueError("Account not found")

        account.deposit(amount)
        self.repository.save(account)


# Example: ACC-1086
repository = AccountRepository()

account = BankAccount("ACC-1086", 1000)
repository.save(account)

service = BankService(repository)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

service.deposit("ACC-1086", 500)

print("After Deposit:", account.get_balance())

try:
    service.deposit("ACC-1086", -100)
except ValueError as e:
    print("Failed:", e)
# Out:
# Account: ACC-1086
# Initial Balance: 1000
# After Deposit: 1500
# Failed: Invalid amount

# %% [markdown]
# ### Q87. Design a plugin-ready payment architecture for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class PaymentPlugin:
    def pay(self, amount):
        raise NotImplementedError


class UPIPayment(PaymentPlugin):
    def pay(self, amount):
        print("Payment processed using UPI")


class CardPayment(PaymentPlugin):
    def pay(self, amount):
        print("Payment processed using Card")


class PaymentService:
    def __init__(self, plugin):
        self.plugin = plugin

    def make_payment(self, account, amount):
        if self.plugin is None:
            raise ValueError("Plugin not available")

        account.withdraw(amount)
        self.plugin.pay(amount)


# Example: ACC-1087
account = BankAccount("ACC-1087", 1000)

service = PaymentService(UPIPayment())

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

service.make_payment(account, 300)

print("Final Balance:", account.get_balance())

try:
    service.make_payment(account, 1000)
except ValueError as e:
    print("Payment failed:", e)
# Out:
# Account: ACC-1087
# Initial Balance: 1000
# Payment processed using UPI
# Final Balance: 700
# Payment failed: Insufficient balance

# %% [markdown]
# ### Q88. Implement a descriptor for positive amounts for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = "_" + name

    def __set__(self, instance, value):
        if not isinstance(value, (int, float)):
            raise TypeError("Amount must be a number")

        if value <= 0:
            raise ValueError("Amount must be positive")

        setattr(instance, self.name, value)

    def __get__(self, instance, owner):
        return getattr(instance, self.name, 0)


class BankAccount:
    amount = PositiveAmount()

    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def deposit(self, amount):
        self.amount = amount
        self._balance += self.amount

    def withdraw(self, amount):
        self.amount = amount

        if self.amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= self.amount

    def get_balance(self):
        return self._balance


# Example: ACC-1088
account = BankAccount("ACC-1088", 1000)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.deposit(500)

print("After Deposit:", account.get_balance())

try:
    account.deposit(-100)
except ValueError as e:
    print("Failed:", e)
# Out:
# Account: ACC-1088
# Initial Balance: 1000
# After Deposit: 1500
# Failed: Amount must be positive

# %% [markdown]
# ### Q89. Use cooperative inheritance with super for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_no, **kwargs):
        super().__init__(**kwargs)

        if not account_no:
            raise ValueError("Invalid account number")

        self.account_no = account_no


class BalanceMixin:
    def __init__(self, balance=0, **kwargs):
        super().__init__(**kwargs)

        if balance < 0:
            raise ValueError("Invalid balance")

        self._balance = balance


class BankAccount(BalanceMixin, Account):
    def __init__(self, account_no, balance):
        super().__init__(
            account_no=account_no,
            balance=balance
        )

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")

        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")

        if amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= amount

    def get_balance(self):
        return self._balance


# Example: ACC-1089
account = BankAccount("ACC-1089", 1000)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.deposit(500)

print("After Deposit:", account.get_balance())

try:
    account.withdraw(2000)
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Account: ACC-1089
# Initial Balance: 1000
# After Deposit: 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q90. Refactor a god object using solid for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def save(self, account):
        print("Account saved:", account.account_no)


class NotificationService:
    def notify(self, message):
        print("Notification:", message)


class BankingService:
    def __init__(self, repository, notification):
        self.repository = repository
        self.notification = notification

    def deposit(self, account, amount):
        account.deposit(amount)
        self.repository.save(account)
        self.notification.notify("Deposit successful")


# Example: ACC-1090
account = BankAccount("ACC-1090", 1000)

service = BankingService(
    AccountRepository(),
    NotificationService()
)

print("Initial Balance:", account.get_balance())

service.deposit(account, 500)

print("Final Balance:", account.get_balance())

try:
    account.withdraw(2000)
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Initial Balance: 1000
# Account saved: ACC-1090
# Notification: Deposit successful
# Final Balance: 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q91. Design an extensible pricing engine for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def get_balance(self):
        return self.__balance


class PricingRule:
    def calculate(self, amount):
        raise NotImplementedError


class FixedFeeRule(PricingRule):
    def __init__(self, fee):
        if fee < 0:
            raise ValueError("Invalid fee")
        self.fee = fee

    def calculate(self, amount):
        return amount + self.fee


class PercentageFeeRule(PricingRule):
    def __init__(self, percentage):
        if percentage < 0:
            raise ValueError("Invalid percentage")
        self.percentage = percentage

    def calculate(self, amount):
        return amount + (amount * self.percentage / 100)


class PricingEngine:
    def __init__(self, rule):
        self.rule = rule

    def final_amount(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        return self.rule.calculate(amount)


# Example: ACC-1091
account = BankAccount("ACC-1091", 1000)

engine = PricingEngine(FixedFeeRule(50))

amount = 500
final_amount = engine.final_amount(amount)

print("Account:", account.account_no)
print("Transaction Amount:", amount)
print("Fee:", 50)
print("Final Amount:", final_amount)

try:
    engine.final_amount(-100)
except ValueError as e:
    print("Transaction failed:", e)
# Out:
# Account: ACC-1091
# Transaction Amount: 500
# Fee: 50
# Final Amount: 550
# Transaction failed: Invalid amount

# %% [markdown]
# ### Q92. Implement an observer for low balance for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LowBalanceObserver:
    def __init__(self, limit):
        self.limit = limit

    def update(self, account):
        if account.get_balance() < self.limit:
            print("Alert: Low balance!")


class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance
        self.observers = []

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount
        self.notify()

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        self.__balance += amount
        self.notify()

    def notify(self):
        for observer in self.observers:
            observer.update(self)

    def get_balance(self):
        return self.__balance


# Example: ACC-1092
account = BankAccount("ACC-1092", 1000)

observer = LowBalanceObserver(500)
account.add_observer(observer)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.withdraw(600)

print("Final Balance:", account.get_balance())
# Out:
# Account: ACC-1092
# Initial Balance: 1000
# Alert: Low balance!
# Final Balance: 400

# %% [markdown]
# ### Q93. Build a state machine for transfer status for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        self.__balance += amount

    def get_balance(self):
        return self.__balance


class Transfer:
    def __init__(self, sender, receiver, amount):
        if amount <= 0:
            raise ValueError("Invalid transfer amount")

        self.sender = sender
        self.receiver = receiver
        self.amount = amount
        self.status = "PENDING"

    def process(self):
        self.status = "PROCESSING"

        try:
            self.sender.withdraw(self.amount)
            self.receiver.deposit(self.amount)
            self.status = "COMPLETED"

        except ValueError:
            self.status = "FAILED"


# Example: ACC-1093
sender = BankAccount("ACC-1093", 1000)
receiver = BankAccount("ACC-1094", 500)

transfer = Transfer(sender, receiver, 300)

print("Initial Status:", transfer.status)

transfer.process()

print("Final Status:", transfer.status)
print("ACC-1093 Balance:", sender.get_balance())
print("ACC-1094 Balance:", receiver.get_balance())
# Out:
# Initial Status: PENDING
# Final Status: COMPLETED
# ACC-1093 Balance: 700
# ACC-1094 Balance: 800

# %% [markdown]
# ### Q94. Create an immutable money value object for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Money:
    def __init__(self, amount, currency):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be a number")

        if amount < 0:
            raise ValueError("Amount cannot be negative")

        if not currency:
            raise ValueError("Currency cannot be empty")

        self.__amount = amount
        self.__currency = currency

    @property
    def amount(self):
        return self.__amount

    @property
    def currency(self):
        return self.__currency


class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, money):
        self.__balance += money.amount

    def withdraw(self, money):
        if money.amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= money.amount

    def get_balance(self):
        return self.__balance


# Example: ACC-1094
account = BankAccount("ACC-1094", 1000)

print("Account:", account.account_no)
print("Initial Balance: ₹1000")

account.deposit(Money(500, "INR"))

print("After Deposit: ₹", account.get_balance())

try:
    account.withdraw(Money(2000, "INR"))
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Account: ACC-1094
# Initial Balance: ₹1000
# After Deposit: ₹ 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q95. Implement a unit-of-work transaction for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class UnitOfWork:
    def transfer(self, sender, receiver, amount):
        if amount <= 0:
            raise ValueError("Invalid transfer amount")

        if amount > sender.get_balance():
            raise ValueError("Transaction failed: Insufficient balance")

        sender.withdraw(amount)
        receiver.deposit(amount)

        print("Transaction committed successfully")


# Example: ACC-1095
sender = BankAccount("ACC-1095", 1000)
receiver = BankAccount("ACC-1096", 500)

uow = UnitOfWork()

print("Before Transfer:")
print("ACC-1095:", sender.get_balance())
print("ACC-1096:", receiver.get_balance())

uow.transfer(sender, receiver, 300)

print("After Transfer:")
print("ACC-1095:", sender.get_balance())
print("ACC-1096:", receiver.get_balance())
# Out:
# Before Transfer:
# ACC-1095: 1000
# ACC-1096: 500
# Transaction committed successfully
# After Transfer:
# ACC-1095: 700
# ACC-1096: 800

# %% [markdown]
# ### Q96. Separate domain and infrastructure layers for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


# INFRASTRUCTURE LAYER
class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_no] = account

    def find(self, account_no):
        return self.accounts.get(account_no)


# APPLICATION LAYER
class BankService:
    def __init__(self, repository):
        self.repository = repository

    def deposit(self, account_no, amount):
        account = self.repository.find(account_no)

        if account is None:
            raise ValueError("Account not found")

        account.deposit(amount)
        self.repository.save(account)


# Example: ACC-1096
repository = AccountRepository()

account = BankAccount("ACC-1096", 1000)
repository.save(account)

service = BankService(repository)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

service.deposit("ACC-1096", 500)

print("After Deposit:", account.get_balance())

try:
    service.deposit("ACC-1096", -100)
except ValueError as e:
    print("Failed:", e)
# Out:
# Account: ACC-1096
# Initial Balance: 1000
# After Deposit: 1500
# Failed: Invalid amount

# %% [markdown]
# ### Q97. Design a plugin-ready payment architecture for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")
        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class PaymentPlugin:
    def pay(self, amount):
        raise NotImplementedError


class UPIPayment(PaymentPlugin):
    def pay(self, amount):
        print("Payment processed using UPI")


class CardPayment(PaymentPlugin):
    def pay(self, amount):
        print("Payment processed using Card")


class PaymentService:
    def __init__(self, plugin):
        self.plugin = plugin

    def make_payment(self, account, amount):
        if self.plugin is None:
            raise ValueError("Plugin not available")

        account.withdraw(amount)
        self.plugin.pay(amount)


# Example: ACC-1097
account = BankAccount("ACC-1097", 1000)

service = PaymentService(UPIPayment())

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

service.make_payment(account, 300)

print("Final Balance:", account.get_balance())

try:
    service.make_payment(account, 1000)
except ValueError as e:
    print("Payment failed:", e)
# Out:
# Account: ACC-1097
# Initial Balance: 1000
# Payment processed using UPI
# Final Balance: 700
# Payment failed: Insufficient balance

# %% [markdown]
# ### Q98. Implement a descriptor for positive amounts for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = "_" + name

    def __set__(self, instance, value):
        if not isinstance(value, (int, float)):
            raise TypeError("Amount must be a number")

        if value <= 0:
            raise ValueError("Amount must be positive")

        setattr(instance, self.name, value)

    def __get__(self, instance, owner):
        return getattr(instance, self.name, 0)


class BankAccount:
    amount = PositiveAmount()

    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self._balance = balance

    def deposit(self, amount):
        self.amount = amount
        self._balance += self.amount

    def withdraw(self, amount):
        self.amount = amount

        if self.amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= self.amount

    def get_balance(self):
        return self._balance


# Example: ACC-1098
account = BankAccount("ACC-1098", 1000)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.deposit(500)

print("After Deposit:", account.get_balance())

try:
    account.deposit(-100)
except ValueError as e:
    print("Failed:", e)
# Out:
# Account: ACC-1098
# Initial Balance: 1000
# After Deposit: 1500
# Failed: Amount must be positive

# %% [markdown]
# ### Q99. Use cooperative inheritance with super for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_no, **kwargs):
        super().__init__(**kwargs)

        if not account_no:
            raise ValueError("Invalid account number")

        self.account_no = account_no


class BalanceMixin:
    def __init__(self, balance=0, **kwargs):
        super().__init__(**kwargs)

        if balance < 0:
            raise ValueError("Invalid balance")

        self._balance = balance


class BankAccount(BalanceMixin, Account):
    def __init__(self, account_no, balance):
        super().__init__(
            account_no=account_no,
            balance=balance
        )

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")

        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")

        if amount > self._balance:
            raise ValueError("Insufficient balance")

        self._balance -= amount

    def get_balance(self):
        return self._balance


# Example: ACC-1099
account = BankAccount("ACC-1099", 1000)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

account.deposit(500)

print("After Deposit:", account.get_balance())

try:
    account.withdraw(2000)
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Account: ACC-1099
# Initial Balance: 1000
# After Deposit: 1500
# Withdrawal failed: Insufficient balance

# %% [markdown]
# ### Q100. Refactor a god object using solid for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankAccount:
    def __init__(self, account_no, balance):
        if not account_no:
            raise ValueError("Invalid account number")

        if balance < 0:
            raise ValueError("Invalid balance")

        self.account_no = account_no
        self.__balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")

        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be positive")

        if amount > self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance -= amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def save(self, account):
        print("Account saved:", account.account_no)


class NotificationService:
    def notify(self, message):
        print("Notification:", message)


class BankingService:
    def __init__(self, repository, notification):
        self.repository = repository
        self.notification = notification

    def deposit(self, account, amount):
        account.deposit(amount)
        self.repository.save(account)
        self.notification.notify("Deposit successful")


# Example: ACC-1100
account = BankAccount("ACC-1100", 1000)

service = BankingService(
    AccountRepository(),
    NotificationService()
)

print("Account:", account.account_no)
print("Initial Balance:", account.get_balance())

service.deposit(account, 500)

print("Final Balance:", account.get_balance())

try:
    account.withdraw(2000)
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Account: ACC-1100
# Initial Balance: 1000
# Account saved: ACC-1100
# Notification: Deposit successful
# Final Balance: 1500
# Withdrawal failed: Insufficient balance
