# %%
text = "Edukron Data science and Data Engineering Batch 2026"
#write the indexing expression to print "Edukron"
print(text[0:7])
# Out:
# Edukron

# %%
text= "Edukron Data science and Data Enginering Batch 2026"
#write the indexing expression to print "Data" (first occurence).
print(text[8:12])
# Out:
# Data

# %%
text = "Edukron Data science and Data Engineering Batch 2026"
#write the indexing expression to print "science"
print(text[13:20])
# Out:
# science

# %%
text = "Edukron Data science and Data Engineering Batch 2026"
#write the indexing expression to print "and"
print(text[21:24])
print(text[-31:-28])
# Out:
# and
# and

# %%
text = "Edukron Data science and Data Engineering Batch 2026"
#write the indexing expression to print "engineering
print(text[-22:-11])
print(text[30:41])
# Out:
# Engineering
# Engineering

# %%
text = "Edukron Data science and Data Engineering Batch 2026"
#write the indexing expression to print "Batch".
print(text[-10:-5])
print(text[42:47])
# Out:
# Batch
# Batch

# %%
text = "Edukron Data science and Data Engineering Batch 2026"
#write the indexing expression to print "2026"
print(len(text))
print(text[-4:])
print(text[-4:-1])
# Out:
# 52
# 2026
# 202

# %%
#write the indexing expression to print "science and Data".
print(text[13:29])
print(text[-39:-23])
# Out:
# science and Data
# science and Data

# %%
#write the indexing expression to print "Data science and Data Engineering Batch".
print(text[8:47])
print(text[-44:47])
print(text[-44:-5])
# Out:
# Data science and Data Engineering Batch
# Data science and Data Engineering Batch
# Data science and Data Engineering Batch
