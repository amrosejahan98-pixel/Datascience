# %%
x =12.20
print(abs(x))
# Out:
# 12.2

# %%
x = 12.255
print(round(x,2))
# Out:
# 12.26

# %%
x=16
print(pow(x,2))
# Out:
# 256

# %%
x=[20,30,40,50,60]
print(max(x))
# Out:
# 60

# %%
x=[20,30,40,50,60]
print(min(x))
# Out:
# 20

# %%
x=[10,20,30]
print(sum(x))
print(type(x))
# Out:
# 60
# <class 'list'>

# %%
x= "data science"
print(len(x))
# Out:
# 12

# %%
x=[20,40,50,60]
print(len(x))
# Out:
# 4

# %%
x=45
y=str(x)
print(y)
print(type(y))
# Out:
# 45
# <class 'str'>

# %%
x=[1,2,3,4]
y=(10,20,30)
z="Edukron"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'str'>

# %%
x=25
y=int(x)
print(bin(y))
# Out:
# 0b11001

# %%
x=25
y=int(x)
print(hex(y))
# Out:
# 0x19

# %%
x=45
y=int(x)
print(oct(y))
# Out:
# 0o55

# %%
x="y"
print(ord(x))
# Out:
# 121

# %%
x=420
print(chr(x))
# Out:
# Ƥ

# %%
x=30
y=20
print(bool(x>25 or x<25))
# Out:
# True

# %%
x=[20,45,35,15,5]
print(sorted(x))
# Out:
# [5, 15, 20, 35, 45]

# %%
x="safdar"
print(sorted(reversed(x)))
# Out:
# ['a', 'a', 'd', 'f', 'r', 's']

# %%
for i in range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
 x="data"
 y="science"
 list(zip(x,y))
# Out:
# [('d', 's'), ('a', 'c'), ('t', 'i'), ('a', 'e')]

# %%
x=[10,20,30]
y=[10,0,15]
print(all(x))
print(all(y))
# Out:
# True
# False

# %%
x=[10,20,30]
y=[10,0,15]
print(all(x))
print(all(y))
# Out:
# True
# False

# %%
x=[10,20,0,15]
y=[10,30,40,20]
print(any(x))
print(any(y))
# Out:
# True
# True

# %%
x=(20,40,50,60)
print(len(x))
# Out:
# 4

# %%
x=[10,20,30,40]
print(sum(x))
# Out:
# 100
